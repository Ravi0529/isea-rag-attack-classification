# %%
import pandas as pd

s = pd.read_parquet("../data/processed/sessions_scored.parquet")
row = s.iloc[0].to_dict()
type(row.get("rule_reasons")), row.get("rule_reasons")
# Out:
# (numpy.ndarray,
#  array(['indicator:cmd_injection', 'behavior:burst_rps>=3'], dtype=object))
